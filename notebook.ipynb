# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Extended_Employee_Performance_and_Productivity_Data.csv")
df
# Out:
#        Employee_ID        Department  Gender  Age   Job_Title  \
# 0                1                IT    Male   55  Specialist
# 1                2           Finance    Male   29   Developer
# 2                3           Finance    Male   55  Specialist
# 3                4  Customer Support  Female   48     Analyst
# 4                5       Engineering  Female   36     Analyst
# ...            ...               ...     ...  ...         ...
# 99995        99996           Finance    Male   27  Technician
# 99996        99997                IT  Female   36  Consultant
# 99997        99998        Operations    Male   53     Analyst
# 99998        99999                HR  Female   22  Consultant
# 99999       100000           Finance  Female   43     Analyst
#
#                         Hire_Date  Years_At_Company Education_Level  \
# 0      2022-01-19 08:03:05.556036                 2     High School
# 1      2024-04-18 08:03:05.556036                 0     High School
# ...

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Department', 'Gender', 'Age', 'Job_Title', 'Hire_Date',
#        'Years_At_Company', 'Education_Level', 'Performance_Score',
#        'Monthly_Salary', 'Work_Hours_Per_Week', 'Projects_Handled',
#        'Overtime_Hours', 'Sick_Days', 'Remote_Work_Frequency', 'Team_Size',
#        'Training_Hours', 'Promotions', 'Employee_Satisfaction_Score',
#        'Resigned'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  float64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
# ...

# %%
cols = ["Employee_ID", "Hire_Date","Work_Hours_Per_Week" ,"Sick_Days" ,"Remote_Work_Frequency" ,"Team_Size", "Training_Hours", "Resigned"]

df.drop(columns= cols, inplace= True)

# %%
df
# Out:
#              Department  Gender  Age   Job_Title  Years_At_Company  \
# 0                    IT    Male   55  Specialist                 2
# 1               Finance    Male   29   Developer                 0
# 2               Finance    Male   55  Specialist                 8
# 3      Customer Support  Female   48     Analyst                 7
# 4           Engineering  Female   36     Analyst                 3
# ...                 ...     ...  ...         ...               ...
# 99995           Finance    Male   27  Technician                 1
# 99996                IT  Female   36  Consultant                 6
# 99997        Operations    Male   53     Analyst                 8
# 99998                HR  Female   22  Consultant                 9
# 99999           Finance  Female   43     Analyst                 0
#
#       Education_Level  Performance_Score  Monthly_Salary  Projects_Handled  \
# 0         High School                  5          6750.0                32
# ...

# %%
df.isnull().sum()
# Out:
# Department                     0
# Gender                         0
# Age                            0
# Job_Title                      0
# Years_At_Company               0
# Education_Level                0
# Performance_Score              0
# Monthly_Salary                 0
# Projects_Handled               0
# Overtime_Hours                 0
# Promotions                     0
# Employee_Satisfaction_Score    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
df.groupby("Department")["Monthly_Salary"].mean().sort_values(ascending= False).plot(kind="bar")
plt.xlabel("Departments")
plt.ylabel("Average salary")
plt.title("Average salary by department")
# Out:
# Text(0.5, 1.0, 'Average salary by department')

# %%
df["Performance_Score"].value_counts()
# Out:
# Performance_Score
# 1    20120
# 2    20013
# 3    19999
# 4    19940
# 5    19928
# Name: count, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      48031
# Female    48001
# Other      3968
# Name: count, dtype: int64

# %%
df.Department.value_counts()
# Out:
# Department
# Marketing           11216
# Finance             11200
# Operations          11181
# IT                  11131
# Sales               11122
# Legal               11118
# Customer Support    11116
# HR                  10960
# Engineering         10956
# Name: count, dtype: int64

# %%
df.Overtime_Hours.describe()
# Out:
# count    100000.000000
# mean         14.514930
# std           8.664026
# min           0.000000
# 25%           7.000000
# 50%          15.000000
# 75%          22.000000
# max          29.000000
# Name: Overtime_Hours, dtype: float64

# %%
df.describe()
# Out:
#                  Age  Years_At_Company  Performance_Score  Monthly_Salary  \
# count  100000.000000     100000.000000      100000.000000   100000.000000
# mean       41.029410          4.476070           2.995430     6403.211000
# std        11.244121          2.869336           1.414726     1372.508717
# min        22.000000          0.000000           1.000000     3850.000000
# 25%        31.000000          2.000000           2.000000     5250.000000
# 50%        41.000000          4.000000           3.000000     6500.000000
# 75%        51.000000          7.000000           4.000000     7500.000000
# max        60.000000         10.000000           5.000000     9000.000000
#
#        Projects_Handled  Overtime_Hours     Promotions  \
# count     100000.000000   100000.000000  100000.000000
# mean          24.431170       14.514930       0.999720
# std           14.469584        8.664026       0.815872
# min            0.000000        0.000000       0.000000
# ...

# %%
df.groupby(["Department", "Performance_Score"])["Overtime_Hours"].mean()
# Out:
# Department        Performance_Score
# Customer Support  1                    14.304464
#                   2                    14.418025
#                   3                    14.748092
#                   4                    14.149146
#                   5                    14.300226
# Engineering       1                    14.464953
#                   2                    14.712191
#                   3                    14.595946
#                   4                    14.570896
#                   5                    14.618502
# Finance           1                    14.387211
#                   2                    14.240463
#                   3                    14.283740
#                   4                    14.343501
#                   5                    14.475252
# HR                1                    14.711942
#                   2                    14.758087
#                   3                    14.484793
# ...

# %%
df.groupby(["Department", "Gender"])["Performance_Score"].mean()
# Out:
# Department        Gender
# Customer Support  Female    2.998092
#                   Male      2.995625
#                   Other     3.005128
# Engineering       Female    3.019698
#                   Male      3.017759
#                   Other     3.057604
# Finance           Female    2.994982
#                   Male      2.972518
#                   Other     2.921277
# HR                Female    2.999810
#                   Male      3.001532
#                   Other     2.924843
# IT                Female    2.989652
#                   Male      3.010436
#                   Other     2.997778
# Legal             Female    2.977782
#                   Male      2.974490
#                   Other     3.122353
# Marketing         Female    2.973319
#                   Male      2.983281
#                   Other     3.038991
# Operations        Female    2.971286
#                   Male      3.044952
#                   Other     2.979730
# ...

# %%
df_num = df.select_dtypes(exclude=["object"])
df_num
# Out:
#        Age  Years_At_Company  Performance_Score  Monthly_Salary  \
# 0       55                 2                  5          6750.0
# 1       29                 0                  5          7500.0
# 2       55                 8                  3          5850.0
# 3       48                 7                  2          4800.0
# 4       36                 3                  2          4800.0
# ...    ...               ...                ...             ...
# 99995   27                 1                  4          4900.0
# 99996   36                 6                  5          8250.0
# 99997   53                 8                  2          4800.0
# 99998   22                 9                  5          8250.0
# 99999   43                 0                  1          4400.0
#
#        Projects_Handled  Overtime_Hours  Promotions  \
# 0                    32              22           0
# 1                    34              13           2
# ...

# %%
df_num.corr()
# Out:
#                                   Age  Years_At_Company  Performance_Score  \
# Age                          1.000000          0.000078           0.001598
# Years_At_Company             0.000078          1.000000           0.001598
# Performance_Score            0.001598          0.001598           1.000000
# Monthly_Salary               0.002757         -0.000645           0.510035
# Projects_Handled            -0.001726          0.002963           0.000640
# Overtime_Hours               0.001875          0.001965          -0.001312
# Promotions                  -0.002888         -0.002737          -0.003501
# Employee_Satisfaction_Score -0.000124         -0.003180           0.001696
#
#                              Monthly_Salary  Projects_Handled  Overtime_Hours  \
# Age                                0.002757         -0.001726        0.001875
# Years_At_Company                  -0.000645          0.002963        0.001965
# ...

# %%
df_num.corr()["Performance_Score"].sort_values()
# Out:
# Promotions                    -0.003501
# Overtime_Hours                -0.001312
# Projects_Handled               0.000640
# Age                            0.001598
# Years_At_Company               0.001598
# Employee_Satisfaction_Score    0.001696
# Monthly_Salary                 0.510035
# Performance_Score              1.000000
# Name: Performance_Score, dtype: float64

# %%
df.head(2)
# Out:
#   Department Gender  Age   Job_Title  Years_At_Company Education_Level  \
# 0         IT   Male   55  Specialist                 2     High School
# 1    Finance   Male   29   Developer                 0     High School
#
#    Performance_Score  Monthly_Salary  Projects_Handled  Overtime_Hours  \
# 0                  5          6750.0                32              22
# 1                  5          7500.0                34              13
#
#    Promotions  Employee_Satisfaction_Score
# 0           0                         2.63
# 1           2                         1.72

# %%
x = df.iloc[:, [4, 7, 9, 10, 11]]
x
x
# Out:
#        Years_At_Company  Monthly_Salary  Overtime_Hours  Promotions  \
# 0                     2          6750.0              22           0
# 1                     0          7500.0              13           2
# 2                     8          5850.0               6           0
# 3                     7          4800.0              28           1
# 4                     3          4800.0              29           1
# ...                 ...             ...             ...         ...
# 99995                 1          4900.0               5           2
# 99996                 6          8250.0               7           1
# 99997                 8          4800.0               6           1
# 99998                 9          8250.0              10           1
# 99999                 0          4400.0              27           1
#
#        Employee_Satisfaction_Score
# 0                             2.63
# 1                             1.72
# 2                             3.17
# ...

# %%
y = df["Performance_Score"]
y
# Out:
# 0        5
# 1        5
# 2        3
# 3        2
# 4        2
#         ..
# 99995    4
# 99996    5
# 99997    2
# 99998    5
# 99999    1
# Name: Performance_Score, Length: 100000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()

# %%
scaled_x_train = scaler.fit_transform(x_train)
scaled_x_train
# Out:
# array([[-0.5155984 , -0.84007799,  0.40227591, -1.22316613,  0.69176408],
#        [-0.86428197,  0.07058454, -1.56007377, -1.22316613, -0.69835826],
#        [-1.56164911,  1.01767358, -1.56007377,  0.00197554, -0.69835826],
#        ...,
#        [ 0.87913589, -0.87650449,  1.67203159, -1.22316613,  0.75258193],
#        [ 1.22781946, -1.45932852, -1.09834443, -1.22316613,  0.96978855],
#        [-1.56164911, -0.40295998,  1.44116692,  0.00197554,  0.96110028]])

# %%
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
scaled_x_test = scaler.fit_transform(x_test)
scaled_x_test
# Out:
# array([[-1.55331106,  0.58046604,  1.09437159, -1.23411999,  1.40042489],
#        [-1.55331106,  1.45510096, -1.09770585, -0.00620099,  1.60921793],
#        [ 1.22943429,  1.0177835 ,  0.5175091 , -1.23411999, -0.65270659],
#        ...,
#        [ 0.88159112,  0.58046604,  1.67123407, -1.23411999, -1.29648511],
#        [-0.50978156,  1.89241842, -1.09770585,  1.22171801, -0.9223976 ],
#        [ 0.88159112, -1.35101941, -0.75158836, -1.23411999, -0.49611182]])

# %%
from sklearn.metrics import accuracy_score

# %%
def model_performance(predict):
    print(f"Accuracy score on model is {accuracy_score(y_test, predict)}")

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %%
lr.fit(scaled_x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(scaled_x_test)
# Out:
# array([4, 5, 5, ..., 5, 5, 1], dtype=int64)

# %%
y_pred = lr.predict(scaled_x_test)

# %%
model_performance(y_pred)
# Out:
# Accuracy score on model is 0.3147

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
parameter_grid = {
    "n_neighbors" : [3,5,7, 11],
    "weights" : ["uniform", "distance"]
}

# %%
gridkn = GridSearchCV(estimator=KNeighborsClassifier(), param_grid=parameter_grid, cv =5)

# %%
gridkn.fit(scaled_x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 11],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'n_neighbors': 3, 'weights': 'distance'}

# %%
y_pred = gridkn.predict(scaled_x_test)

# %%
model_performance(y_pred)
# Out:
# Accuracy score on model is 0.4968

# %%
from sklearn.svm import SVC

# %%
s_model  = SVC()

# %%
parameter_grid = {
    "C" : [0.01, 0.1, 1.0],
    "kernel" : ["linear","poly"]
}

# %%
gridsvc = GridSearchCV(estimator=s_model, param_grid= parameter_grid, cv = 2)

# %%
gridsvc.fit(scaled_x_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1.0], 'kernel': ['linear', 'poly']})

# %%
y_pred = gridsvc.predict(scaled_x_test)

# %%
model_performance(y_pred)
# Out:
# Accuracy score on model is 0.3475

# %%
joblib.dump(gridsvc, "svc_model.pkl")
# Out:
# ['svc_model.pkl']
